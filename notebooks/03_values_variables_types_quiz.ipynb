# %% [markdown]
# # Values, Variables, and Types Quiz
#
# Run the hidden setup cell first, then display the quiz widget.

# %%
#| echo: false
from fcpython.quiz_banks import values_variables_types_quiz
from fcpython.widgets import show_quiz

quiz = values_variables_types_quiz()

# %%
show_quiz(quiz)
